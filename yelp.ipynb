# %% [markdown]
# <a href="https://colab.research.google.com/github/elizabethavargas/cloud-hw1/blob/master/yelp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Yelp API by Cuisine
# Add Yelp API Key as a secret: In the left panel of Colab, click the "🔑" icon.

# %%
# import and installs
# !pip install requests
import requests
from google.colab import userdata

# load api key from secrets
YELP_API_KEY = userdata.get('YELP_API_KEY')

if YELP_API_KEY is None:
    print("Error: YELP_API_KEY not found in Colab secrets. Please add it.")
else:
    print("Yelp API Key loaded successfully.")

# %%
all_businesses_data = []

# %%
# Define the Yelp API endpoint for business search
API_HOST = 'https://api.yelp.com'
SEARCH_PATH = '/v3/businesses/search'

# Set up the authorization header with your API key
headers = {
    'Authorization': f'Bearer {YELP_API_KEY}'
}

for offset in range(0, 300, 50):  # 0, 50, 100, 150
    params = {
        'term': 'restaurant',
        'location': 'New York City',
        'categories': 'newamerican',
        'limit': 50,
        'offset': offset
    }

    response = requests.get(
        f'{API_HOST}{SEARCH_PATH}',
        headers=headers,
        params=params
    )

    if response.status_code == 200:
        data = response.json()
        businesses = data.get('businesses', [])

        print(f"Fetched {len(businesses)} businesses at offset {offset}")

        all_businesses_data.extend(businesses)
    else:
        print(f"Error: {response.status_code} - {response.text}")
        break
# Out:
# Fetched 50 businesses at offset 0
# Fetched 50 businesses at offset 50
# Fetched 50 businesses at offset 100
# Fetched 50 businesses at offset 150
# Error: 400 - {"error": {"code": "VALIDATION_ERROR", "description": "Too many results requested, limit+offset must be <= 240."}}

# %%
params = {
      'term': 'restaurant',
      'location': 'New York City',
      'categories': 'newamerican',
      'limit': 40,
      'offset': 200
  }

response = requests.get(
    f'{API_HOST}{SEARCH_PATH}',
    headers=headers,
    params=params
)

if response.status_code == 200:
    data = response.json()
    businesses = data.get('businesses', [])

    print(f"Fetched {len(businesses)} businesses at offset {offset}")

    all_businesses_data.extend(businesses)
else:
    print(f"Error: {response.status_code} - {response.text}")
# Out:
# Fetched 40 businesses at offset 200

# %%
len(all_businesses_data )
# Out:
# 240

# %%
all_businesses_data[100]
# Out:
# {'id': 'uq5rHbGtBFwCwPkokIkKvQ',
#  'alias': 'jojo-new-york-3',
#  'name': 'JoJo',
#  'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/bO5CEUDgQ_0QZIwKqQeqfQ/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/jojo-new-york-3?adjust_creative=p6mhJwsttIzMzP5Ln3malA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=p6mhJwsttIzMzP5Ln3malA',
#  'review_count': 293,
#  'categories': [{'alias': 'newamerican', 'title': 'New American'},
#   {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#  'rating': 3.9,
#  'coordinates': {'latitude': 40.76506, 'longitude': -73.96571},
#  'transactions': ['pickup', 'delivery'],
#  'price': '$$$',
#  'location': {'address1': '160 E 64th St',
#   'address2': '',
#   'address3': None,
#   'city': 'New York',
#   'zip_code': '10065',
#   'country': 'US',
#   'state': 'NY',
#   'display_address': ['160 E 64th St', 'New York, NY 10065']},
#  'phone': '+12122235656',
#  'display_phone': '(212) 223-5656',
# ...

# %%
# save all_business_data as pickle
import pickle
with open('newamerican.pickle', 'wb') as f:
    pickle.dump(all_businesses_data, f)
