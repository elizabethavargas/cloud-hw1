# %% [markdown]
# <a href="https://colab.research.google.com/github/elizabethavargas/cloud-hw1/blob/master/other_scripts/yelp_opensearch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Upload Yelp Restaurant Data to Open Search

# %%
# install packages
# !pip install boto3
# !pip install opensearch-py
# !pip install requests-aws4auth
# Out:
# Requirement already satisfied: boto3 in /usr/local/lib/python3.12/dist-packages (1.42.54)
# Requirement already satisfied: botocore<1.43.0,>=1.42.54 in /usr/local/lib/python3.12/dist-packages (from boto3) (1.42.54)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from boto3) (1.1.0)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /usr/local/lib/python3.12/dist-packages (from boto3) (0.16.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.12/dist-packages (from botocore<1.43.0,>=1.42.54->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.12/dist-packages (from botocore<1.43.0,>=1.42.54->boto3) (2.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.43.0,>=1.42.54->boto3) (1.17.0)
# Requirement already satisfied: opensearch-py in /usr/local/lib/python3.12/dist-packages (3.1.0)
# Requirement already satisfied: urllib3!=2.2.0,!=2.2.1,<3,>=1.26.19 in /usr/local/lib/python3.12/dist-packages (from opensearch-py) (2.5.0)
# Requirement already satisfied: requests<3.0.0,>=2.32.0 in /usr/local/lib/python3.12/dist-packages (from opensearch-py) (2.32.4)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from opensearch-py) (2.9.0.post0)
# Requirement already satisfied: certifi>=2024.07.04 in /usr/local/lib/python3.12/dist-packages (from opensearch-py) (2026.1.4)
# Requirement already satisfied: Events in /usr/local/lib/python3.12/dist-packages (from opensearch-py) (0.5)
# Requirement already satisfied: opensearch-protobufs==0.19.0 in /usr/local/lib/python3.12/dist-packages (from opensearch-py) (0.19.0)
# Requirement already satisfied: protobuf>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from opensearch-protobufs==0.19.0->opensearch-py) (5.29.6)
# Requirement already satisfied: grpcio>=1.68.1 in /usr/local/lib/python3.12/dist-packages (from opensearch-protobufs==0.19.0->opensearch-py) (1.78.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.0->opensearch-py) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.0->opensearch-py) (3.11)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil->opensearch-py) (1.17.0)
# Requirement already satisfied: typing-extensions~=4.12 in /usr/local/lib/python3.12/dist-packages (from grpcio>=1.68.1->opensearch-protobufs==0.19.0->opensearch-py) (4.15.0)
# Requirement already satisfied: requests-aws4auth in /usr/local/lib/python3.12/dist-packages (1.3.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from requests-aws4auth) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->requests-aws4auth) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->requests-aws4auth) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->requests-aws4auth) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->requests-aws4auth) (2026.1.4)

# %% [markdown]
# ### Open Saved Data

# %%
import pickle
with open('yelp_restaurants.pickle', 'rb') as f:
  yelp_restaurants = pickle.load(f)

# %%
yelp_restaurants[1]
# Out:
# {'id': 'mNeyjjcfrXdGf_mCyoolkw',
#  'alias': 'lolas-new-york',
#  'name': "Lola's",
#  'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/mqY1TlTF7-zwNlR1hjDlJg/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/lolas-new-york?adjust_creative=p6mhJwsttIzMzP5Ln3malA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=p6mhJwsttIzMzP5Ln3malA',
#  'review_count': 80,
#  'categories': [{'alias': 'newamerican', 'title': 'New American'}],
#  'rating': 4.6,
#  'coordinates': {'latitude': 40.74481688811193, 'longitude': -73.9878205},
#  'transactions': [],
#  'location': {'address1': '2 W 28th St',
#   'address2': '',
#   'address3': None,
#   'city': 'New York',
#   'zip_code': '10001',
#   'country': 'US',
#   'state': 'NY',
#   'display_address': ['2 W 28th St', 'New York, NY 10001']},
#  'phone': '',
#  'display_phone': '',
#  'distance': 2216.123384764452,
#  'business_hours': [{'open': [{'is_overnight': False,
#      'start': '1700',
#      'end': '2100',
#      'day': 0},
#     {'is_overnight': False, 'start': '1700', 'end': '2130', 'day': 1},
#     {'is_overnight': False, 'start': '1700', 'end': '2130', 'day': 2},
#     {'is_overnight': False, 'start': '1700', 'end': '2130', 'day': 3},
#     {'is_overnight': False, 'start': '1700', 'end': '2130', 'day': 4},
#     {'is_overnight': False, 'start': '1700', 'end': '2130', 'day': 5},
#     {'is_overnight': False, 'start': '1700', 'end': '2100', 'day': 6}],
#    'hours_type': 'REGULAR',
#    'is_open_now': True}],
#  'attributes': {'business_temp_closed': None,
#   'menu_url': 'https://www.lolasnyc.com/menu',
#   'open24_hours': None,
#   'waitlist_reservation': None}}

# %%
# convert restaurant info into correct format
restaurants = []
category_map = {
    # MEXICAN
    "Mexican": "Mexican",
    "New Mexican Cuisine": "Mexican",
    "Tex-Mex": "Mexican",
    "Tacos": "Mexican",
    "Latin American": "Mexican",

    # CHINESE
    "Chinese": "Chinese",
    "Cantonese": "Chinese",
    "Dim Sum": "Chinese",
    "Hainan": "Chinese",
    "Hong Kong Style Cafe": "Chinese",
    "Shanghainese": "Chinese",
    "Szechuan": "Chinese",
    "Taiwanese": "Chinese",

    # ITALIAN
    "Italian": "Italian",
    "Pizza": "Italian",
    "Pasta Shops": "Italian",
    "Sicilian": "Italian",
    "Tuscan": "Italian",

    # INDIAN
    "Indian": "Indian",
    "Pakistani": "Indian",
    "Bangladeshi": "Indian",
    "Sri Lankan": "Indian",
    "Himalayan/Nepalese": "Indian",

    # NEW AMERICAN
    "New American": "American",
    "American": "American",
    "Southern": "American",
    "Comfort Food": "American",
    "Steakhouses": "American",
    "Seafood": "American",
    "Burgers": "American",
    "Breakfast & Brunch": "American",
    "Diners": "American",
    "Gastropubs": "American",
    "Barbeque": "American"}

for r in yelp_restaurants:
  cuisine = None
  for c in r['categories']:
    if c['title'] in category_map.keys():
      cuisine = category_map[c['title']]
      break

  restaurants.append({"RestaurantID": r["id"],
    "Cuisine": cuisine})

# %%
len(restaurants)
# Out:
# 1189

# %% [markdown]
# ### Insert Restaurants into Open Search

# %%
from google.colab import userdata

# load AWS key from secrets
AWS_KEY = userdata.get('AWS_KEY').strip()
AWS_SECRET = userdata.get('AWS_SECRET').strip()

# %%
from opensearchpy import OpenSearch, RequestsHttpConnection, helpers
from requests_aws4auth import AWS4Auth
import boto3

# AWS credentials
region = "us-east-1"
service = "es"

awsauth = AWS4Auth(
    AWS_KEY,
    AWS_SECRET,
    region,
    service,
    session_token=None
)

# OpenSearch client
host = "search-domain1-otwi6xtzh23sgx5uo3vq75hfei.us-east-1.es.amazonaws.com"

client = OpenSearch(
    hosts=[{"host": host, "port": 443}],
    http_auth=awsauth,
    use_ssl=True,
    verify_certs=True,
    connection_class=RequestsHttpConnection
)

# Prepare bulk actions
actions = [
    {
        "_index": "restaurants",
        "_source": restaurant
    }
    for restaurant in restaurants
]

# Bulk insert
helpers.bulk(client, actions)

print("Bulk insert completed!")
# Out:
# Bulk insert completed!

# %% [markdown]
# ### Check the Table

# %%
response = client.search(
    index="restaurants",
    body={"query": {"match_all": {}}}
)

print(response)
# Out:
# {'took': 115, 'timed_out': False, '_shards': {'total': 5, 'successful': 5, 'skipped': 0, 'failed': 0}, 'hits': {'total': {'value': 1189, 'relation': 'eq'}, 'max_score': 1.0, 'hits': [{'_index': 'restaurants', '_id': 'q6NkhpwBhvVSU2OaS29l', '_score': 1.0, '_source': {'RestaurantID': 'zRXMvxUX_rOliKZPpkWi_g', 'Cuisine': 'American'}}, {'_index': 'restaurants', '_id': 'raNkhpwBhvVSU2OaS29l', '_score': 1.0, '_source': {'RestaurantID': 'Q-zg3X3OQ0gNABmwlgiczw', 'Cuisine': 'American'}}, {'_index': 'restaurants', '_id': 'r6NkhpwBhvVSU2OaS29l', '_score': 1.0, '_source': {'RestaurantID': 'SaYTVG7wHCMDBofHCgXPaA', 'Cuisine': 'American'}}, {'_index': 'restaurants', '_id': 'sKNkhpwBhvVSU2OaS29l', '_score': 1.0, '_source': {'RestaurantID': 'z5hRX3iJ5Ty_S38iG_WY3Q', 'Cuisine': 'American'}}, {'_index': 'restaurants', '_id': 'tKNkhpwBhvVSU2OaS29l', '_score': 1.0, '_source': {'RestaurantID': 'OfKH43VSRWrrv35jC9upAA', 'Cuisine': 'American'}}, {'_index': 'restaurants', '_id': 'vKNkhpwBhvVSU2OaS29l', '_score': 1.0, '_source': {'RestaurantID': 'h37t9rA06Sr4EetJjKrfzw', 'Cuisine': 'Italian'}}, {'_index': 'restaurants', '_id': 'v6NkhpwBhvVSU2OaS29l', '_score': 1.0, '_source': {'RestaurantID': 'Xd_l7jtUAZZAAvK8-mI2Jw', 'Cuisine': 'American'}}, {'_index': 'restaurants', '_id': 'xKNkhpwBhvVSU2OaS29l', '_score': 1.0, '_source': {'RestaurantID': 'OgM6WwztLVavBQBmb_g5aw', 'Cuisine': 'American'}}, {'_index': 'restaurants', '_id': 'y6NkhpwBhvVSU2OaS29l', '_score': 1.0, '_source': {'RestaurantID': 'kXW-IKPBMSRO9Gja2oPdSA', 'Cuisine': 'American'}}, {'_index': 'restaurants', '_id': '0qNkhpwBhvVSU2OaS29l', '_score': 1.0, '_source': {'RestaurantID': 'sBL7J7s4Rnul40-MB0hXbA', 'Cuisine': 'American'}}]}}
